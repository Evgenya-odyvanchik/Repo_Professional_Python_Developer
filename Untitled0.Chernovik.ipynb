# %%
name = "Андрей"
print(name)
# Out:
# Андрей

# %%
age = 25
name = "Sasha"
print(age, name)
# Out:
# 25 Sasha

# %%
print("Доброе утро!)")
# Out:
# Доброе утро!)

# %%
print(80/40)
# Out:
# 2.0

# %%
print("молоко ---", 80)
print("колбаса ---", 500)
print("хлеб ---", 50)
print("скмма покупки ---", 80+500+50)
# Out:
# молоко --- 80
# колбаса --- 500
# хлеб --- 50
# скмма покупки --- 630

# %%
name ="Андрей"
print(name)
# Out:
# Андрей

# %%
sugar = 3
eggs = 1
flour = 3
apples = 1
print("Сахар", sugar, "ст.л")
print("Яйца", eggs, "шт")
print("Мука", flour, "ст.л")
print("яблко", apples, "шт")
# Out:
# Сахар 3 ст.л
# Яйца 1 шт
# Мука 3 ст.л
# яблко 1 шт

# %%
print("2")        # Вывод: 2 (строка, тип str)
print(int("2"))   # Вывод: 2 (число, тип int)
print("2" + "2")  # Вывод: 22 (конкатенация строк)
print(int("2") + int("2"))  # Вывод: 4 (сложение чисел)
# Out:
# 2
# 2
# 22
# 4

# %%
print("Однажды по дорожке "
      "Я шел к себе домой "
      "Смотрю и вижу: кошки "
      "Сидят ко мне спиной")
# Out:
# Однажды по дорожке Я шел к себе домой Смотрю и вижу: кошки Сидят ко мне спиной

# %%
print('''Однажды по дорожке
Я шел к себе домой 
Смотрю и вижу: кошки
Сидят ко мне спиной''')
# Out:
# Однажды по дорожке
# Я шел к себе домой
# Смотрю и вижу: кошки
# Сидят ко мне спиной

# %%
print("""Однажды по дорожке
Я шел к себе домой 
Смотрю и вижу: кошки
Сидят ко мне спиной""")
# Out:
# Однажды по дорожке
# Я шел к себе домой
# Смотрю и вижу: кошки
# Сидят ко мне спиной

# %%
print("Разс", "Двас", "Трис")
# Out:
# Разс Двас Трис

# %%
print("раз", "два", "три", sep=" и ")
# Вывод: раз и два и три
# Out:
# раз и два и три

# %%
print("день", "месяц", "год", sep=" / ")
# Out:
# день / месяц / год

# %%
print("раз", "два", "три", sep=" ")
# Вывод: раздватри
# Out:
# раз два три

# %%
print("имя", "возраст", "город", sep=",")
# Вывод: имя,возраст,город
# Out:
# имя,возраст,город

# %%
print("C:", "Users", "user", "Documents", "2.НЕ ПЕРЕКИНУТОЕ",  sep="\\")
# Вывод: C:\Users\John
# Out:
# C:\Users\user\Documents\2.НЕ ПЕРЕКИНУТОЕ

# %%
print("+7", "999", "123-45-67", sep=" ")
# Вывод: +7 999 123-45-67
# Out:
# +7 999 123-45-67

# %%
print("Однажды \nпо дорожке \nя шёл \nк себе домой")
# Out:
# Однажды
# по дорожке
# я шёл
# к себе домой

# %%
print("milk", end=" ")
print("cat", end=" ")
# Out:
# milk cat

# %%
print("Однажды ", end="")
print("По дорожке ", end="")
print("Я шел", end="")
print("К себе домой", end="")
# Out:
# Однажды По дорожке Я шелК себе домой

# %%
print("milk", end="\n---\n")
print("cat", end="\n---\n")
# Out:
# milk
# ---
# cat
# ---

# %%
print('"milk", "cat"')
print("'milk', 'cat'")
print("milk", "cat", sep=",")
print("""'milk', 'cat'""")
# Out:
# "milk", "cat"
# 'milk', 'cat'
# milk,cat
# 'milk', 'cat'

# %%
print('введите в терминале \'yes\' or \'no\' ')
print("Введите в терминале \"да\" или \"нет\" ")
# Out:
# введите в терминале 'yes' or 'no'
# Введите в терминале "да" или "нет"

# %%
print("Введите в терминале "да" или "нет"")
# Out:
#   Cell In[52], line 1
#     print("Введите в терминале "да" или "нет"")
#                                 ^
# SyntaxError: invalid syntax. Is this intended to be part of the string?

# %%
print("Скажи: 'Привет!'")  # Ошибка!
# Out:
# Скажи: 'Привет!'

# %%
print("1.\tЯблоко\n2.\tБанан\n3.\tАпельсин")
# Out:
# 1.	Яблоко
# 2.	Банан
# 3.	Апельсин

# %%
print("Hello\rWorld")  # В некоторых средах выведет "Worldlo" (перезапись)
# Out:
# World

# %%
name = 'Aндрей'
surname = 'Соколов'
print(name* 3)
print(name + ' ' + surname)
print(name, surname, sep=",")
# Out:
# AндрейAндрейAндрей
# Aндрей Соколов
# Aндрей,Соколов

# %%
print(name + surname)  # Выведет: АндрейСоколов
# Out:
# AндрейСоколов

# %%
print('Возраст: ' + str(age))  # Выведет: Возраст: 5
# Out:
# Возраст: 5

# %%
print(name, surname, sep=' -> ')  # Выведет: Андрей -> Соколов
# Out:
# Aндрей -> Соколов

# %%
print(f"{name} {surname}")
# Out:
# Aндрей Соколов

# %%
print(name * 5, surname * 5)
# Out:
# AндрейAндрейAндрейAндрейAндрей СоколовСоколовСоколовСоколовСоколов

# %%
my_string = '''используем тройные кавычки,
чтобы разместить "текст" 
на нескольких строчках
для удобства чтения кода'''
print(my_string)
# Out:
# используем тройные кавычки,
# чтобы разместить "текст"
# на нескольких строчках
# для удобства чтения кода

# %%
name = "pole"
print(type(name))
# Out:
# <class 'str'>

# %%
height = 1.75
print(type(height))
# Out:
# <class 'float'>

# %%
is_student = True
print(type(is_student))
# Out:
# <class 'bool'>

# %%
fruits = ["яблоко", "банан", "апельсин"]
print(type(fruits))
# Out:
# <class 'list'>

# %%
name = input()
print("Вы ввели", name)
# Out:
# Вы ввели Женя

# %%
phone_model = input("Введите телефон")
print("вы хотите приобрести", phone_model)
# Out:
# вы хотите приобрести honor

# %%
name_student = input("какой студент вам нужен?")
print("Вам нужен студент", name_student)
# Out:
# Вам нужен студент Евгения

# %%
age_1 = input("Сколько лет студенту?")
age_1_int = int(age_1)
print("Возраст студента", age_1 )
# Out:
# Возраст студента 34

# %%
age_1 = input("Сколько лет студенту?")
age_1_type = type(age_1)
print("Возраст студента", age_1_type )
# Out:
# Возраст студента <class 'str'>

# %%
age_1 = input("Сколько лет студенту?")
age_1_str = str(age_1)
print("Возраст студента", age_1_str )
# Out:
# Возраст студента 34

# %%
phone_model = input("стоимость")
summa_s_kreditom = phone_model * 2
print("стоимость с кредитом составляет",  summa_s_kreditom)
# Out:
# стоимость с кредитом составляет 1000010000

# %%
price = 35.5
my_str =  "цена мороженного" + str(price)
print(my_str)
# Out:
# цена мороженного35.5

# %%
a = int("68")*3
b = int(33.5)+ 29
c = a + b
print(c, name, surname)
# Out:
# 266 Женя Соколов

# %%
a = float("55.5") * 3
b = float("36.6")+ 8
c = a * b
print(c, a, b)
# Out:
# 7425.900000000001 166.5 44.6

# %%
price_str = input("цена тел")
price_str = int(price_str)
year = int(input("год выпуска"))
money = float(input("денег в наличии"))
print(price_str, year, money)
# Out:
# 10000 2002 11.562

# %%
price = input("цена тел")
price_int = int(price)
cena_s_kred = price_int * 0.2
print("Цена с кредитом", cena_s_kred)
# Out:
# Цена с кредитом 4.0

# %%
first_1 = 'skypro'
first_2 = 'Hello'
print(first_2 + ', ' + first_1 + "!")
# Out:
# Hello, skypro!

# %%
first_1 = "skypro"
first_2 = "Hello"
print(f"{first_2}, {first_1}")
# Out:
# Hello, skypro

# %%
namber = 3.154645
r_number = round(namber, 3)
print(r_number)

namber = 3.73423532
r_number = round(namber)
print(r_number)
# Out:
# 3.155
# 4

# %%
print(f'"I know," he said, "that I heard him say \'help me\' as he fell."')
print(f'"I haven\'t ever seen such a strange and wonderful fish," Mr. Smith said.')

print(f'"I know," he said, "that I heard him say \'help me\' as he fell."')
print(f'"I haven\'t ever seen such a strange and wonderful fish," Mr. Smith said.')

#«Я знаю, — сказал он, — что слышал, как он, падая, произнёс: „Помогите мне“».
#«Я никогда не видел такой странной и удивительной рыбы», — сказал мистер Смит.
# Out:
# "I know," he said, "that I heard him say 'help me' as he fell."
# "I haven't ever seen such a strange and wonderful fish," Mr. Smith said.
# "I know," he said, "that I heard him say 'help me' as he fell."
# "I haven't ever seen such a strange and wonderful fish," Mr. Smith said.
